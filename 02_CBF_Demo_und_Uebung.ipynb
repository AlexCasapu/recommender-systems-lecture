# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexCasapu/recommender-systems-lecture/blob/main/02_CBF_Demo_und_Uebung.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Datensatz: Bücher und deren Beschreibung/Keywords
books = pd.DataFrame({
    'Titel': ['Peppa Pig', 'Harry Potter', 'Maths for 5th grade'],
    'Keywords': ['Toddlers book',
                 'Childrens book 8+',
                 'Maths book for elementary school']
})

# TF-IDF Vektorisierung (Wörter in Zahlen umwandeln)
tfidf_matrix = tfidf.fit_transform(books['Keywords'])

# Kosinus-Ähnlichkeit berechnen
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)
print("Kosinus-Ähnlichkeit zwischen den Büchern:")
print(cosine_sim)
# Out:
# Kosinus-Ähnlichkeit zwischen den Büchern:
# [[1.         0.25861529 0.16412926]
#  [0.25861529 1.         0.16412926]
#  [0.16412926 0.16412926 1.        ]]

# %%
# ÜBUNG: Content-Based Filtering
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Datensatz: Artikelbeschreibungen in einem Online-Shop
products = pd.DataFrame({
    'Produkt': ['Laptop Pro', 'Gaming PC', 'Kaffeemaschine', 'Espressokocher'],
    'Beschreibung': ['Schneller Laptop für Office und Programmieren',
                     'Leistungsstarker PC für Gaming und Rendering',
                     'Automatische Kaffeemaschine für schnellen Kaffee',
                     'Klassischer Espressokocher für starken Kaffee']
})

# TODO 1: Initialisiere den TfidfVectorizer
# TODO 2: Transformiere die 'Beschreibung' in eine TF-IDF Matrix
# TODO 3: Berechne die Kosinus-Ähnlichkeit
# Out:
# [[1.         0.18265783 0.06238155 0.06238155]
#  [0.18265783 1.         0.06238155 0.06238155]
#  [0.06238155 0.06238155 1.         0.22956641]
#  [0.06238155 0.06238155 0.22956641 1.        ]]

# %% [markdown]
# # MUSTERLÖSUNG
# # TODO 1
# vectorizer = TfidfVectorizer()
# # TODO 2
# matrix = vectorizer.fit_transform(products['Beschreibung'])
# # TODO 3
# sim_matrix = cosine_similarity(matrix, matrix)
# print(sim_matrix)
