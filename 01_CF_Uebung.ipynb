# %%
# 1. COLLABORATIVE FILTERING (CF)
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# Wir nutzen einen erweiterten Filmdatensatz (User-Item Rating Matrix)
data = {
    'Matrix': [5, 4, 1, 1, 3],
    'Inception': [4, 5, 2, 1, 4],
    'Titanic': [1, 1, 5, 4, 2],
    'Notebook': [2, 1, 4, 5, 1],
    'Avatar': [5, 4, 2, 2, 4]
}
ratings = pd.DataFrame(data, index=['Alice', 'Tom', 'Lisa', 'Max', 'John'])
ratings
# Out:
#        Matrix  Inception  Titanic  Notebook  Avatar
# Alice       5          4        1         2       5
# Tom         4          5        1         1       4
# Lisa        1          2        5         4       2
# Max         1          1        4         5       2
# John        3          4        2         1       4

# %%
# Wer ist Alice am ähnlichsten? User Based CF
user_similarity = ratings.T.corr(method='pearson')
user_similarity
# Out:
#           Alice       Tom      Lisa       Max      John
# Alice  1.000000  0.882735 -0.971537 -0.848485  0.781071
# Tom    0.882735  1.000000 -0.894575 -0.956296  0.922410
# Lisa  -0.971537 -0.894575  1.000000  0.887783 -0.723478
# Max   -0.848485 -0.956296  0.887783  1.000000 -0.886621
# John   0.781071  0.922410 -0.723478 -0.886621  1.000000

# %%
# Alternativer Algorithmus: Welche Filme sind sich ähnlich, basierend darauf, WIE sie bewertet wurden? Item-Based CF
# Wir füllen NaN (falls vorhanden) mit 0 für die Cosine Similarity
ratings_filled = ratings.fillna(0)

# Cosine Similarity zwischen den Items (Spalten)
item_sim_matrix = cosine_similarity(ratings_filled.T)
item_similarity = pd.DataFrame(item_sim_matrix, index=ratings.columns, columns=ratings.columns)
item_similarity
# Out:
#              Matrix  Inception   Titanic  Notebook    Avatar
# Matrix     1.000000   0.968646  0.485468  0.525924  0.980430
# Inception  0.968646   1.000000  0.574271  0.555746  0.976650
# Titanic    0.485468   0.574271  1.000000  0.957447  0.633231
# Notebook   0.525924   0.555746  0.957447  1.000000  0.651324
# Avatar     0.980430   0.976650  0.633231  0.651324  1.000000

# %%
# ÜBUNG: Collaborative Filtering
# TODO 1: Finden Sie heraus, welcher Film dem Film 'Matrix' am ähnlichsten ist.
# Nutzen Sie dafür die berechnete 'item_similarity' Matrix aus der vorherigen Zelle.

matrix_aehnlichkeit = item_similarity['_______'].drop('_______').sort_values(ascending=False)

matrix_aehnlichkeit
# Out:
# Avatar       0.980430
# Inception    0.968646
# Notebook     0.525924
# Titanic      0.485468
# Name: Matrix, dtype: float64
